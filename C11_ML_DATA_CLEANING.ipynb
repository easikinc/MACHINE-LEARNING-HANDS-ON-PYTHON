# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv('/home/utkarss/MACHINE LEARNING HANDS ON PYTHON/DataSheets/NFL.csv')
# Out:
# /tmp/ipykernel_94945/2525920272.py:1: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('/home/utkarss/MACHINE LEARNING HANDS ON PYTHON/DataSheets/NFL.csv')

# %%
data.head()
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %%
cat_var=data.select_dtypes(include=['O'])

# %%
cat_var.head(10)
# Out:
#          Date   time SideofField posteam DefensiveTeam  \
# 0  2009-09-10  15:00         TEN     PIT           TEN
# 1  2009-09-10  14:53         PIT     PIT           TEN
# 2  2009-09-10  14:16         PIT     PIT           TEN
# 3  2009-09-10  13:35         PIT     PIT           TEN
# 4  2009-09-10  13:27         PIT     PIT           TEN
# 5  2009-09-10  13:16         TEN     TEN           PIT
# 6  2009-09-10  12:40         TEN     TEN           PIT
# 7  2009-09-10  12:11         TEN     TEN           PIT
# 8  2009-09-10  11:34         TEN     TEN           PIT
# 9  2009-09-10  11:24         TEN     PIT           TEN
#
#                                                 desc ExPointResult  \
# 0  R.Bironas kicks 67 yards from TEN 30 to PIT 3....           NaN
# 1  (14:53) B.Roethlisberger pass short left to H....           NaN
# 2  (14:16) W.Parker right end to PIT 44 for -3 ya...           NaN
# 3  (13:35) (Shotgun) B.Roethlisberger pass incomp...           NaN
# ...

# %%
error_pct=cat_var.isnull().sum()/cat_var.shape[0]*100

# %%
error_key=error_pct[error_pct>50].keys()

# %%
d_cleaned_data=cat_var.drop(error_key,axis=1)

# %%
d_cleaned_data
# Out:
#               Date   time SideofField posteam DefensiveTeam  \
# 0       2009-09-10  15:00         TEN     PIT           TEN
# 1       2009-09-10  14:53         PIT     PIT           TEN
# 2       2009-09-10  14:16         PIT     PIT           TEN
# 3       2009-09-10  13:35         PIT     PIT           TEN
# 4       2009-09-10  13:27         PIT     PIT           TEN
# ...            ...    ...         ...     ...           ...
# 362442  2017-01-01  00:22          GB     DET            GB
# 362443  2017-01-01  00:13          GB     DET            GB
# 362444  2017-01-01  00:13         DET      GB           DET
# 362445  2017-01-01  00:12         DET      GB           DET
# 362446  2017-01-01  00:00         DET      GB           DET
#
#                                                      desc     PlayType  \
# 0       R.Bironas kicks 67 yards from TEN 30 to PIT 3....      Kickoff
# 1       (14:53) B.Roethlisberger pass short left to H....         Pass
# ...

# %%
missing_var=d_cleaned_data.isnull().mean()*100

# %%
missing_var
# Out:
# Date              0.000000
# time              0.000000
# SideofField       0.124156
# posteam           6.064059
# DefensiveTeam     6.064059
# desc              0.000552
# PlayType          0.000000
# Tackler1         40.608144
# HomeTeam          0.000000
# AwayTeam          0.000000
# dtype: float64

# %%
# select which have 0% or more error or impurities in your cols
miss_keys=missing_var[missing_var>0].keys()

# %%
miss_keys
d_cleaned_data['time'].isnull().sum()
# Out:
# 0

# %%
time_cleaned_data=d_cleaned_data['time'].fillna(d_cleaned_data['time'].mode()[0])

# %%
d_cleaned_data['time'].isnull().sum()
# Out:
# 0

# %%
# only time column have cleaned now we cleaned all columns by the loop
for var in miss_keys:
    d_cleaned_data[var].fillna(d_cleaned_data[var].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_94945/1800085267.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d_cleaned_data[var].fillna(d_cleaned_data[var].mode()[0],inplace=True)

# %%
d_cleaned_data.isnull().sum()
# Out:
# Date             0
# time             0
# SideofField      0
# posteam          0
# DefensiveTeam    0
# desc             0
# PlayType         0
# Tackler1         0
# HomeTeam         0
# AwayTeam         0
# dtype: int64

# %% [markdown]
# # Thankyou data has cleared now you can rejoin it in your dataset or can apply other methods like median mode and mean also
