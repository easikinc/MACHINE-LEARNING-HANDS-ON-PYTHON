# %% [markdown]
# # Matplotlib Subplot Creation

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#plt.subplot(row,column,index_location)
plt.subplot(2,2,1)
#Showing two lines in a one plot
x=np.arange(2024,2030)
y=[0,20,56,28,90,76]
z=[45,76,23,55,22,59]
plt.plot(x,y,color='b',marker='o',linestyle='--',linewidth=1,markersize=5 , label='Delhi')
plt.plot(x,z,color='g',marker='o',linestyle='--',linewidth=1,markersize=5 , label='Mumbai')
plt.title('Delhi temprature',fontsize=13)
plt.xlabel('Year',fontsize=15)
plt.ylabel('Temprature',fontsize=15)
plt.axis(xmin=2023,ymin=0)
plt.legend(loc=2)
# 2 plot
plt.subplot(2,2,2)
Classes=['IT','CS','Elx','civil','Machanical']
students=[57,77,67,76,34,]
plt.pie(students,labels=Classes,autopct='%0.1F%%', explode=[0.1,0.3,0,0.1,0],colors=['c','m','y','b','g'])
# plot 3
plt.subplot(2,2,3)

CS=[12,33,55,77,88]
Year=['2019','2020','2021','2022','2023']
IT=[56,54,45,55,46]
Elx=[78,89,34,34,24]
year_index=np.arange(len(Year))
width=0.2
plt.title('Collage of Technology')

plt.bar(year_index,CS,width,label='CSE',color='red',)
plt.bar(year_index+width,IT , width,label='IT',color='green',)
plt.bar(year_index+(width*2),Elx, width,label='Elx',color='yellow')
plt.xticks(year_index+width,Year, rotation=20)
plt.xlabel(' Year')
plt.ylabel('Number of Students')
plt.legend()
# Plot 6
plt.subplot(2,2,4,projection='polar',facecolor='k',frameon=False)

plt.show()

# %%
# plots
plt.subplot(3,2,1)
x=np.arange(2024,2030)
y=[0,20,56,28,90,76]
z=[45,76,23,55,22,59]
plt.plot(x,y,color='b',marker='o',linestyle='--',linewidth=1,markersize=5 , label='Delhi')
plt.plot(x,z,color='g',marker='o',linestyle='--',linewidth=1,markersize=5 , label='Mumbai')
plt.title('Delhi temprature',fontsize=13)
plt.xlabel('Year',fontsize=15)
plt.ylabel('Temprature',fontsize=15)
plt.axis(xmin=2023,ymin=0)
plt.legend(loc=2)
plt.subplot(3,2,2)
plt.pie([1/2])
plt.subplot(3,2,3)
x=np.arange(2024,2030)
y=[0,20,56,28,90,76]
plt.plot(x,y)
plt.title('Delhi temprature')
plt.xlabel('Year')
plt.ylabel('Temprature')
plt.axis(xmin=2023,ymin=0)
plt.subplot(3,2,4)
CS=[12,33,55,77,88]
Year=['2019','2020','2021','2022','2023']
IT=[56,54,45,55,46]
Elx=[78,89,34,34,24]
year_index=np.arange(len(Year))
width=0.2
plt.title('Collage of Technology')

plt.bar(year_index,CS,width,label='CSE',color='red',)
plt.bar(year_index+width,IT , width,label='IT',color='green',)
plt.bar(year_index+(width*2),Elx, width,label='Elx',color='yellow')
plt.xticks(year_index+width,Year, rotation=20)
plt.xlabel(' Year')
plt.ylabel('Number of Students')
plt.legend()
plt.subplot(3,2,5)
Classes=['IT','CS','Elx','civil','Machanical']
students=[57,77,67,76,34,]
plt.pie(students,labels=Classes,autopct='%0.1F%%', explode=[0.1,0.3,0,0.1,0],colors=['c','m','y','b','g'])
plt.subplot(3,2,6,projection='polar',facecolor='k',frameon=False)
plt.show()

# %%
# Save this figure into directory use plt.savefig('nameoffileorpath',quality=value<100,dpi=sizeofimage,facecolor='color')

# %%
# plots
plt.subplot(3,2,1)
x=np.arange(2024,2030)
y=[0,20,56,28,90,76]
z=[45,76,23,55,22,59]
plt.plot(x,y,color='b',marker='o',linestyle='--',linewidth=1,markersize=5 , label='Delhi')
plt.plot(x,z,color='g',marker='o',linestyle='--',linewidth=1,markersize=5 , label='Mumbai')
plt.title('Delhi temprature',fontsize=13)
plt.xlabel('Year',fontsize=15)
plt.ylabel('Temprature',fontsize=15)
plt.axis(xmin=2023,ymin=0)
plt.legend(loc=2)
plt.subplot(3,2,2)
plt.pie([1/2])
plt.subplot(3,2,3)
x=np.arange(2024,2030)
y=[0,20,56,28,90,76]
plt.plot(x,y)
plt.title('Delhi temprature')
plt.xlabel('Year')
plt.ylabel('Temprature')
plt.axis(xmin=2023,ymin=0)
plt.subplot(3,2,4)
CS=[12,33,55,77,88]
Year=['2019','2020','2021','2022','2023']
IT=[56,54,45,55,46]
Elx=[78,89,34,34,24]
year_index=np.arange(len(Year))
width=0.2
plt.title('Collage of Technology')

plt.bar(year_index,CS,width,label='CSE',color='red',)
plt.bar(year_index+width,IT , width,label='IT',color='green',)
plt.bar(year_index+(width*2),Elx, width,label='Elx',color='yellow')
plt.xticks(year_index+width,Year, rotation=20)
plt.xlabel(' Year')
plt.ylabel('Number of Students')
plt.legend()
plt.subplot(3,2,5)
Classes=['IT','CS','Elx','civil','Machanical']
students=[57,77,67,76,34,]
plt.pie(students,labels=Classes,autopct='%0.1F%%', explode=[0.1,0.3,0,0.1,0],colors=['c','m','y','b','g'])
plt.subplot(3,2,6,projection='polar',facecolor='k',frameon=False)
# Saving this figure
plt.savefig('/home/utkarss/MACHINE LEARNING HANDS ON PYTHON/images/chart.png')
plt.show()
